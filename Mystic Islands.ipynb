# %% [markdown]
# # What this file does

# %% [markdown]
# In this notebook, I query NJPropertyRecords' (https://njpropertyrecords.com/) real estate records for properties in Little Egg Harbor. I will later compare mailing addresses to property locations after some manual fixing of discrepancies in the way that addresses are formatted. (See: Executing the comparison.ipynb)
#
# I got municipal, block and lot codes (called GIS codes by NJPropertyRecords and PAMS_PIN numbers by Ocean County) from Tom Thorsen, GIS Specialist at the Ocean County Department of Planning. I filter the data he gave me for Little Egg Harbor by the zipcode for Mystic Island, grab the codes and use them in my API query urls. I ended up querying my 8000+ urls in two batches because it took so long, parsed the responses and saved my relevant results in two csvs.

# %% [markdown]
# # Getting Mystic Island property records

# %%
#importing libraries

# %%
import pandas as pd

# %%
#read in data

# %%
# !ls
# Out:
# 340291517_M4_2018.xls Mystic Islands.ipynb

# %%
#property codes from Ocean County

# %%
df = pd.read_excel('340291517_M4_2018.xls')

# %%
#find equivalent of GIS Pin in this dataset

# %%
df.dtypes
# Out:
# OBJECTID       int64
# CtyDstNo       int64
# BlockNo       object
# LotNo         object
# QualCode      object
#                ...
# UNIQUEID      object
# PAMS_PIN      object
# New_Record    object
# Error         object
# Duplicate     object
# Length: 84, dtype: object

# %%
#list of all codes for places in Mystic Island using MI's zipcode

# %%
list_codes = df[df['ZipCode']==8087]['PAMS_PIN'].to_list()

# %%
#API requesting

# %%
import requests

# %%
#for one address

# %%
response = requests.get('https://njpropertyrecords.com/api/property/1517_314_42/property-view')
data = response.json()
print(data)
# Out:
# {'propertyInformation': {'Updated': '2016-11-16', 'GIS_PIN': '1517_314_42', 'PRIOR_GIS_PIN': '', 'COUNTY_NAME': 'Ocean', 'DISTRICT_NAME': 'Little Egg Harbor', 'Municipality': '1517', 'Block': '314', 'Lot': '42', 'Qual': None, 'Property_Location': '8 WEST BOAT DRIVE', 'Owners_Name': 'CLANCY, LINDA M', 'Owners_Mailing_Address': '8 W BOAT DR', 'City_State_Zip': 'LITTLE EGG HARBOR  NJ  08', 'Deed_Book': '14361', 'Deed_Page': '402', 'Sale_Price': 1, 'Sale_Date': '2009-07-16', 'NU_Code': '14', 'Property_Class': '2', 'Building_Class': '16', 'Land_Desc': '50X90', 'Building_Desc': '1S-AL-R    1064', 'Class_4_Code': '0', 'Yr_Built': 1958, 'Zone': 'R-50', 'Sq_Ft': 1064, 'Acreage': 0.1033, 'Map_Page': '52', 'Additional_Lots': None, 'Taxes_1': 3820.73, 'Taxes_2': 0, 'Taxes_3': 0, 'Taxes_4': 0, 'Sp_Tax_Cd_1': 'F02', 'Sp_Tax_Cd_2': None, 'Sp_Tax_Cd_3': None, 'Sp_Tax_Cd_4': None, 'TaxRate': '', 'TaxRatio': '', 'RateYear': '', 'RatioYear': '', 'Veterans_CNT': '0', 'Senior_Citizens_CNT': '0', 'Widows_CNT': '0', 'Surv_Spouse_CNT': '0', 'Disabled_CNT': '0', 'Deduction_Amount': '0', 'LastYearTax': '3820.73', 'EPL_Own': '0', 'EPL_Use': '0', 'EPL_Desc': '0', 'EPL_Statute': None, 'EPL_Init': '000000', 'EPL_Further': '000000', 'EPL_Facility_Name': None, 'Prior_Block': None, 'Prior_Lot': None, 'Prior_Qual': None, 'Ratio': 15880000, 'Type_Use': None, 'Bank_Code': '660', 'Account': None, 'Mortgage_Account': None, 'Year_1': 2019, 'Owner_1': 'CLANCY, LINDA M', 'Street_1': '8 W BOAT DR', 'City_State_Zip_1': 'LITTLE EGG HARBOR  NJ  08087', 'Land_Assmnt_1': '78400', 'Building_Assmnt_1': '80400', 'Exempt_1': '0', 'Assessed_1': 158800, 'Total_Assmnt_1': 158800, 'Year_2': 2018, 'Owner_2': 'CLANCY, LINDA M', 'Street_2': '8 W BOAT DR', 'City_State_Zip_2': 'LITTLE EGG HARBOR  NJ  08087', 'Land_Assmnt_2': '78400', 'Building_Assmnt_2': '80400', 'Exempt_2': '0', 'Assessed_2': 158800, 'Total_Assmnt_2': 158800, 'Year_3': 2017, 'Owner_3': 'CLANCY, LINDA M', 'Street_3': '8 W BOAT DR', 'City_State_Zip_3': 'LITTLE EGG HARBOR  NJ  08087', 'Land_Assmnt_3': '78400', 'Building_Assmnt_3': '80400', 'Exempt_3': '0', 'Assessed_3': 158800, 'Total_Assmnt_3': 158800, 'Year_4': 2016, 'Owner_4': 'CLANCY, LINDA M', 'Street_4': '8 W BOAT DR', 'City_State_Zip_4': 'LITTLE EGG HARBOR  NJ  08087', 'Land_Assmnt_4': '78400', 'Building_Assmnt_4': '80400', 'Exempt_4': '0', 'Assessed_4': 158800, 'Total_Assmnt_4': 158800, 'Latitude': None, 'Longitude': None, 'Free1': None, 'Free2': None, 'StyDesc': None, 'Style': None, 'CalcTaxAmt': None, 'EQValue': None, 'O_City': 'HARBOR EGG LITTLE', 'O_State': 'NJ', 'O_Zip': '08087', 'P_City': 'Tuckerton', 'P_State': 'NJ', 'P_Zip': '08087', 'Yr_Built_Raw': None, 'Additional_Lots_Parsed': None, 'Prop_Mail_ErrorCode': '', 'Owner_Mail_ErrorCode': '', 'Prop_Mail_HouseNum': '8', 'Prop_Mail_StreetName': 'Boat', 'Prop_Mail_Suffix': 'Dr', 'Prop_Mail_SUD': '', 'Prop_Mail_City': 'Tuckerton', 'Prop_Mail_State': 'NJ', 'Prop_Mail_Zip': '08087', 'Prop_Mail_Zip4': '1615', 'Prop_Mail_UnitNum': '', 'Prop_Mail_Suite': '', 'Prop_Mail_Company': '', 'Prop_Mail_PreDir': 'W', 'Prop_Mail_PostDir': '', 'Prop_Mail_Street': '8 W Boat Dr', 'Prop_Mail_Street2': '', 'Prop_Mail_CRRT': 'C013', 'Prop_Mail_DPV': '', 'Prop_Mail_LeftOvers': '', 'Prop_Mail_RDI': '', 'Prop_Mail_Corrections': 'AT23', 'Prop_Mail_ResultCode': '1', 'Owner_Mail_HouseNum': '8', 'Owner_Mail_StreetName': 'Boat', 'Owner_Mail_Suffix': 'Dr', 'Owner_Mail_SUD': '', 'Owner_Mail_City': 'Ltl Egg Hbr', 'Owner_Mail_State': 'NJ', 'Owner_Mail_Zip': '08087', 'Owner_Mail_Zip4': '1615', 'Owner_Mail_UnitNum': '', 'Owner_Mail_Suite': '', 'Owner_Mail_Company': '', 'Owner_Mail_PreDir': 'W', 'Owner_Mail_PostDir': '', 'Owner_Mail_Street': '8 W Boat Dr', 'Owner_Mail_Street2': '', 'Owner_Mail_CRRT': 'C013', 'Owner_Mail_DPV': '', 'Owner_Mail_LeftOvers': '', 'Owner_Mail_RDI': '', 'Owner_Mail_Corrections': 'APT', 'Owner_Mail_ResultCode': '1', 'DEED_DATE': None, 'REPORTED_SALES_PRICE': '', 'VERIFIED_SALES_PRICE': '', 'SR_NU_CODE': '', 'ASSESSOR_NU_CO ...

# %%
#for roughly half of addresses

# %%
list_dict = []
for code in list_codes:
    response = requests.get(f'https://njpropertyrecords.com/api/property/{code}/property-view')
    data = response.json()
    list_dict += [data]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-2e3e38b6da6b> in <module>
#       1 list_dict = []
#       2 for code in list_codes:
# ----> 3     response = requests.get(f'https://njpropertyrecords.com/api/property/{code}/property-view')
#       4     data = response.json()
#       5     list_dict += [data]
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#seeing how far we got before I interrupted to make sure everything was fine (it took a while!)

# %%
len(list_dict)
# Out:
# 3733

# %%
#structuring the data I want

# %%
new_list = []
for element in list_dict:
    new_dict = {}
    try:
        new_dict['Code'] = (element['propertyInformation']['GIS_PIN'])
    except:
        pass
    try:
        new_dict['Property_Location'] = (element['propertyInformation']['Property_Location'])
    except:
        pass
    try: 
         new_dict['Mailing Address'] = (element['propertyInformation']['Owners_Mailing_Address'])
    except:
        pass
    new_list += [new_dict]

# %%
#converting to dataframe

# %%
df_half = pd.DataFrame(new_list)

# %%
#converting to csv

# %%
df_half.to_csv('top_half_property_Mystic.csv')

# %%
#getting the index of where I stopped

# %%
list_codes.index(new_list[-1]['Code'])
# Out:
# 3732

# %%
#slicing out the rest

# %%
list_codes[3733::]
# Out:
# ['1517_285.06_4',
#  '1517_285.06_5',
#  '1517_285.06_6',
#  '1517_285.06_7',
#  '1517_285.06_8',
#  '1517_285.06_9',
#  '1517_285.06_10',
#  '1517_285.06_11',
#  '1517_285.06_12',
#  '1517_285.06_13',
#  '1517_285.06_14',
#  '1517_285.06_15',
#  '1517_285.06_16',
#  '1517_285.06_17',
#  '1517_285.06_18',
#  '1517_285.06_19',
#  '1517_285.06_20',
#  '1517_285.06_21',
#  '1517_285.06_22',
#  '1517_285.06_23',
#  '1517_285.06_24',
#  '1517_285.06_25',
#  '1517_285.06_26',
#  '1517_285.06_27',
#  '1517_285.06_28',
#  '1517_285.06_29',
#  '1517_285.06_30',
#  '1517_285.06_32',
#  '1517_285.06_33',
#  '1517_285.06_34',
#  '1517_285.06_35',
#  '1517_285.06_36',
#  '1517_285.06_37',
#  '1517_285.06_38',
#  '1517_285.07_1',
#  '1517_285.07_2',
#  '1517_285.07_3',
#  '1517_285.07_4',
#  '1517_316_39',
#  '1517_316_40',
#  '1517_317_4',
#  '1517_317_7',
#  '1517_317_8',
#  '1517_317_9',
#  '1517_317_10',
#  '1517_317_11',
#  '1517_317_12',
#  '1517_317_13',
#  '1517_317_18',
#  '1517_317_20',
#  '1517_317_21',
#  '1517_318_27',
#  '1517_318_28',
#  '1517_318_30',
#  '1517_318_33',
#  '1517_318_40',
#  '1517_318_41',
#  '1517_318_43',
#  '1517_318_45',
#  '1517_318_46',
#  '1517_319_2',
#  '1517_319_3',
#  '1517_319_5',
#  '1517_319_8',
#  '1517_319_11',
#  '1517_319_17',
#  '1517_319_18',
#  '1517_319_19',
#  '1517_319_20',
#  '1517_319_21',
#  '1517_320_4',
#  '1517_320_5',
#  '1517_320_6',
#  '1517_320_14',
#  '1517_320_15',
#  '1517_320_19',
#  '1517_320_25.01',
#  '1517_321_1',
#  '1517_321_4',
#  '1517_321_5',
#  '1517_321_6',
#  '1517_321_8',
#  ...]

# %%
#querying p 2

# %%
list_dict = []
for code in list_codes[3733::]:
    response = requests.get(f'https://njpropertyrecords.com/api/property/{code}/property-view')
    data = response.json()
    list_dict += [data]

# %%
# look out for west, east, drive, road, court, south, north, #way, avenue, route, lane, street in next book

# %%
#confirming I got everything

# %%
len(list_dict)
# Out:
# 4933

# %%
#structuring the data I want again

# %%
new_list = []
for element in list_dict:
    new_dict = {}
    try:
        new_dict['Code'] = (element['propertyInformation']['GIS_PIN'])
    except:
        pass
    try:
        new_dict['Property_Location'] = (element['propertyInformation']['Property_Location'])
    except:
        pass
    try: 
         new_dict['Mailing Address'] = (element['propertyInformation']['Owners_Mailing_Address'])
    except:
        pass
    new_list += [new_dict]

# %%
#confirming we picked up where we left off, no issues

# %%
list_codes.index(new_list[0]['Code'])
# Out:
# 3733

# %%
# list to dataframe

# %%
df_bottom_half = pd.DataFrame(new_list)

# %%
df_bottom_half
# Out:
#                 Code         Property_Location      Mailing Address
# 0      1517_285.06_4  14 SUNRISE BAY BOULEVARD  14 SUNRISE BAY BLVD
# 1      1517_285.06_5  16 SUNRISE BAY BOULEVARD       16 SUNRISE BAY
# 2      1517_285.06_6  18 SUNRISE BAY BOULEVARD  18 SUNRISE BAY BLVD
# 3      1517_285.06_7  20 SUNRISE BAY BOULEVARD  20 SUNRISE BAY BLVD
# 4      1517_285.06_8  22 SUNRISE BAY BOULEVARD  22 SUNRISE BAY BLVD
# ...              ...                       ...                  ...
# 4928  1517_331.07_14         22 SEA ISLE DRIVE       22 SEA ISLE DR
# 4929  1517_331.07_15         21 SEA ISLE DRIVE       21 SEA ISLE DR
# 4930  1517_331.07_17         17 SEA ISLE DRIVE       17 SEA ISLE DR
# 4931   1517_333.33_1      80 EAST ANCHOR DRIVE      124 E ANCHOR DR
# 4932   1517_333.33_3         EAST ANCHOR DRIVE      124 E ANCHOR DR
#
# [4933 rows x 3 columns]

# %%
#dataframe to csv

# %%
df_bottom_half.to_csv('bottom_half_property_Mystic.csv')
